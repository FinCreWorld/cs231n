# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from Assignment 1. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# Setup cell.
import time
import sys
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver
sys.path.append("../")
from mytools.tune_params import *

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )
    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.   
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.300479089768492
# W1 relative error: 1.0252674471656573e-07
# W2 relative error: 2.212047930816777e-05
# W3 relative error: 4.5623278145362223e-07
# b1 relative error: 4.660094372886962e-09
# b2 relative error: 2.085654124402131e-09
# b3 relative error: 1.689724888469736e-10
# Running check with reg =  3.14
# Initial loss:  5.940411485412347
# W1 relative error: 1.409028728052923e-08
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 3.7977687598347537e-07
# b1 relative error: 1.475242751587128e-08
# b2 relative error: 1.7223751746766738e-09
# b3 relative error: 2.378772438198909e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
from tqdm import tqdm

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 9e-2   # Experiment with this!
learning_rate = 1e-3 # Experiment with this!

model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 260.571127
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.113000
# (Epoch 1 / 20) train acc: 0.360000; val_acc: 0.140000
# (Epoch 2 / 20) train acc: 0.520000; val_acc: 0.152000
# (Epoch 3 / 20) train acc: 0.620000; val_acc: 0.130000
# (Epoch 4 / 20) train acc: 0.820000; val_acc: 0.159000
# (Epoch 5 / 20) train acc: 0.920000; val_acc: 0.154000
# (Iteration 11 / 40) loss: 2.590106
# (Epoch 6 / 20) train acc: 0.960000; val_acc: 0.147000
# (Epoch 7 / 20) train acc: 0.960000; val_acc: 0.143000
# (Epoch 8 / 20) train acc: 0.960000; val_acc: 0.147000
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.136000
# (Iteration 21 / 40) loss: 0.001915
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.136000
# (Iteration 31 / 40) loss: 0.000028
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.136000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.136000

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
from tqdm import tqdm

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

learning_rate = 1e-3  # Experiment with this!

ws = 10**(np.linspace(np.log10(1e-6), np.log10(1), 7, True))
activition_by_weight(ws,
                     lambda w: FullyConnectedNet(
                       [100, 100],
                       weight_scale=w,
                       dtype=np.float64
                     ),
                     lambda model: Solver(
                       model, small_data, num_epochs=20, batch_size=25, 
                       update_rule='sgd', optim_config={"learning_rate": learning_rate},
                       verbose=False
                     ))

# 通过上述模块找到相对合适的weight_scale
# 发现 weight_scale 的分布要尽可能均衡
# 当 weight_scale 较小时，分布呈若干尖峰
# 当 weight_scale 较大时，分布仅在 x=0 处呈现尖峰
# 需要选取分布尽可能均衡的 weight_scale，同时 weight_scale 尽可能大？
# 保证激活分布的均匀性？

# 使用同样的手法寻找 learning_rate
# 效果一般般
# 但是当learning_rate 过大时，结果也呈现尖峰
# Out:
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# d:\CNN\cs231n\assignment2\cs231n\layers.py:30: RuntimeWarning: overflow encountered in matmul
#   out = x.reshape(N, -1) @ w + b
# d:\CNN\cs231n\assignment2\cs231n\layers.py:30: RuntimeWarning: invalid value encountered in matmul
#   out = x.reshape(N, -1) @ w + b
# d:\CNN\cs231n\assignment2\cs231n\layers.py:147: RuntimeWarning: invalid value encountered in subtract
#   f = x.copy() - x.max(axis=1).reshape(-1, 1)
# d:\CNN\cs231n\assignment2\cs231n\classifiers\fc_net.py:221: RuntimeWarning: overflow encountered in square
#   loss += 0.5 * self.reg * np.sum(np.square(self.params[f'W{i}']))
# d:\CNN\cs231n\assignment2\cs231n\classifiers\fc_net.py:221: RuntimeWarning: invalid value encountered in double_scalars
#   loss += 0.5 * self.reg * np.sum(np.square(self.params[f'W{i}']))
# count nan:  0
# count total:  (307200,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  1000
# count total:  (1000,)

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.
from tqdm import tqdm


num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 3e-2   # Experiment with this!
lr = 10**(np.linspace(-6, 0, 20, True))

train_acc_by_lr(lr,
                lambda : FullyConnectedNet(
                  [100, 100],
                  weight_scale=weight_scale,
                  dtype=np.float64
                ),
                lambda model, learning_rate: Solver(
                  model,
                  small_data,
                  num_epochs=20,
                  batch_size=25,
                  update_rule="sgd",
                  optim_config={"learning_rate": learning_rate},
                  verbose=False
                ))
# Out:
#  85%|████████▌ | 17/20 [00:12<00:02,  1.31it/s]d:\CNN\cs231n\assignment2\cs231n\layers.py:64: RuntimeWarning: invalid value encountered in matmul
#   dw = x.reshape(x.shape[0], -1).T @ dout
#  90%|█████████ | 18/20 [00:12<00:01,  1.31it/s]D:\Environment\anaconda3\envs\cs231n\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 20/20 [00:14<00:00,  1.39it/s]
# [0.08,
#  0.1,
#  0.16,
#  0.1,
#  0.1,
#  0.22800000000000004,
#  0.388,
#  0.664,
#  0.9879999999999999,
#  0.9879999999999999,
#  1.0,
#  1.0,
#  1.0,
#  0.22399999999999998,
#  0.08,
#  0.16,
#  0.16,
#  0.08,
#  0.08,
#  0.08]

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-1
learning_rate = 1e-3

model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 136.647581
# (Epoch 0 / 20) train acc: 0.260000; val_acc: 0.126000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 2 / 20) train acc: 0.320000; val_acc: 0.113000
# (Epoch 3 / 20) train acc: 0.480000; val_acc: 0.123000
# (Epoch 4 / 20) train acc: 0.700000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.860000; val_acc: 0.142000
# (Iteration 11 / 40) loss: 2.127869
# (Epoch 6 / 20) train acc: 0.960000; val_acc: 0.130000
# (Epoch 7 / 20) train acc: 1.000000; val_acc: 0.133000
# (Epoch 8 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.132000
# (Iteration 21 / 40) loss: 0.000990
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.132000
# (Iteration 31 / 40) loss: 0.000432
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.132000

# %%
num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scales = 10**np.linspace(-2, 0, 7, True)
activition_by_weight(
  weight_scales=weight_scales,
  model_generator=lambda w: FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=w,
    dtype=np.float64
  ),
  solver_generator=lambda model: Solver(
    model,
    small_data,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
    verbose=False
  ))
# Out:
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# d:\CNN\cs231n\assignment2\cs231n\layers.py:150: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(f[np.arange(N), y] / f_sum))
# d:\CNN\cs231n\assignment2\cs231n\layers.py:30: RuntimeWarning: overflow encountered in matmul
#   out = x.reshape(N, -1) @ w + b
# d:\CNN\cs231n\assignment2\cs231n\layers.py:147: RuntimeWarning: invalid value encountered in subtract
#   f = x.copy() - x.max(axis=1).reshape(-1, 1)
# d:\CNN\cs231n\assignment2\cs231n\layers.py:63: RuntimeWarning: overflow encountered in matmul
#   dx = dout @ w.T
# d:\CNN\cs231n\assignment2\cs231n\layers.py:117: RuntimeWarning: invalid value encountered in multiply
#   dx = (x > 0) * dout
# count nan:  0
# count total:  (307200,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  1000
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (10000,)
# count nan:  0
# count total:  (1000,)
# count nan:  0
# count total:  (307200,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  10000
# count total:  (10000,)
# count nan:  1000
# count total:  (1000,)

# %%
num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}
weight_scale = 1e-1
learning_rates = 10**np.linspace(-6, 0, 7, False)
train_acc_by_lr(learning_rates=learning_rates,
                model_generator=lambda :FullyConnectedNet(
                  [100, 100, 100, 100],
                  weight_scale=weight_scale,
                  dtype=np.float64
                ),
                solver_generator=lambda model, learning_rate: Solver(
                  model,
                  small_data,
                  num_epochs=20,
                  batch_size=25,
                  update_rule='sgd',
                  optim_config={'learning_rate': learning_rate},
                  verbose=False
                ))
# Out:
#  71%|███████▏  | 5/7 [00:03<00:01,  1.23it/s]d:\CNN\cs231n\assignment2\cs231n\layers.py:30: RuntimeWarning: invalid value encountered in matmul
#   out = x.reshape(N, -1) @ w + b
# d:\CNN\cs231n\assignment2\cs231n\layers.py:64: RuntimeWarning: invalid value encountered in matmul
#   dw = x.reshape(x.shape[0], -1).T @ dout
# d:\CNN\cs231n\assignment2\cs231n\classifiers\fc_net.py:221: RuntimeWarning: overflow encountered in square
#   loss += 0.5 * self.reg * np.sum(np.square(self.params[f'W{i}']))
# d:\CNN\cs231n\assignment2\cs231n\classifiers\fc_net.py:221: RuntimeWarning: invalid value encountered in double_scalars
#   loss += 0.5 * self.reg * np.sum(np.square(self.params[f'W{i}']))
# D:\Environment\anaconda3\envs\cs231n\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 7/7 [00:05<00:00,  1.27it/s]
# [0.136, 0.192, 0.784, 1.0, 0.9960000000000001, 0.08, 0.08]

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# The five-layer network obviously more sensitive to the initialization scale. Because it's easier to be saturated.

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")
    
for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.677070
# (Epoch 0 / 5) train acc: 0.120000; val_acc: 0.114000
# (Iteration 11 / 200) loss: 2.286775
# (Iteration 21 / 200) loss: 2.213708
# (Iteration 31 / 200) loss: 2.133093
# (Epoch 1 / 5) train acc: 0.230000; val_acc: 0.233000
# (Iteration 41 / 200) loss: 2.047191
# (Iteration 51 / 200) loss: 2.083705
# (Iteration 61 / 200) loss: 1.987867
# (Iteration 71 / 200) loss: 2.030746
# (Epoch 2 / 5) train acc: 0.286000; val_acc: 0.242000
# (Iteration 81 / 200) loss: 1.976083
# (Iteration 91 / 200) loss: 1.941871
# (Iteration 101 / 200) loss: 1.952206
# (Iteration 111 / 200) loss: 1.960190
# (Epoch 3 / 5) train acc: 0.308000; val_acc: 0.259000
# (Iteration 121 / 200) loss: 1.798618
# (Iteration 131 / 200) loss: 1.772049
# (Iteration 141 / 200) loss: 1.844964
# (Iteration 151 / 200) loss: 1.857053
# (Epoch 4 / 5) train acc: 0.326000; val_acc: 0.296000
# (Iteration 161 / 200) loss: 1.803706
# (Iteration 171 / 200) loss: 1.887731
# (Iteration 181 / 200) loss: 1.912509
# (Iteration 191 / 200) loss: 1.883468
# (Epoch 5 / 5) train acc: 0.381000; val_acc: 0.296000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.600476
# (Epoch 0 / 5) train acc: 0.107000; val_acc: 0.112000
# (Iteration 11 / 200) loss: 2.219461
# (Iteration 21 / 200) loss: 2.152334
# (Iteration 31 / 200) loss: 1.957530
# (Epoch 1 / 5) train acc: 0.327000; val_acc: 0.278000
# (Iteration 41 / 200) loss: 1.848199
# (Iteration 51 / 200) loss: 1.836232
# (Iteration 61 / 200) loss: 1.718964
# (Iteration 71 / 200) loss: 1.612866
# (Epoch 2 / 5) train acc: 0.401000; val_acc: 0.309000
# (Iteration 81 / 200) loss: 1.776547
# (Iteration 91 / 200) loss: 1.814599
# (Iteration 101 / 200) loss: 1.680876
# (Iteration 111 / 200) loss: 1.614487
# (Epoch 3 / 5) train acc: 0.418000; val_acc: 0.296000
# (Iteration 121 / 200) loss: 1.690150
# (Iteration 131 / 200) loss: 1.504481
# (Iteration 141 / 200) loss: 1.714617
# (Iteration 151 / 200) loss: 1.526337
# (Epoch 4 / 5) train acc: 0.481000; val_acc: 0.313000
# (Iteration 161 / 200) loss: 1.530065
# (Iteration 171 / 200) loss: 1.321562
# (Iteration 181 / 200) loss: 1.352797
# (Iteration 191 / 200) loss: 1.461788
# (Epoch 5 / 5) train acc: 0.546000; val_acc: 0.361000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()
    
fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")
    
for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 3.143658
# (Epoch 0 / 5) train acc: 0.110000; val_acc: 0.118000
# (Iteration 11 / 200) loss: 2.130801
# (Iteration 21 / 200) loss: 1.884012
# (Iteration 31 / 200) loss: 1.830986
# (Epoch 1 / 5) train acc: 0.403000; val_acc: 0.325000
# (Iteration 41 / 200) loss: 1.647163
# (Iteration 51 / 200) loss: 1.822207
# (Iteration 61 / 200) loss: 1.554568
# (Iteration 71 / 200) loss: 1.674090
# (Epoch 2 / 5) train acc: 0.463000; val_acc: 0.360000
# (Iteration 81 / 200) loss: 1.584118
# (Iteration 91 / 200) loss: 1.624375
# (Iteration 101 / 200) loss: 1.447382
# (Iteration 111 / 200) loss: 1.382262
# (Epoch 3 / 5) train acc: 0.504000; val_acc: 0.370000
# (Iteration 121 / 200) loss: 1.524876
# (Iteration 131 / 200) loss: 1.456360
# (Iteration 141 / 200) loss: 1.430291
# (Iteration 151 / 200) loss: 1.218456
# (Epoch 4 / 5) train acc: 0.513000; val_acc: 0.376000
# (Iteration 161 / 200) loss: 1.125660
# (Iteration 171 / 200) loss: 1.289807
# (Iteration 181 / 200) loss: 1.150808
# (Iteration 191 / 200) loss: 1.350441
# (Epoch 5 / 5) train acc: 0.585000; val_acc: 0.375000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.515734
# (Epoch 0 / 5) train acc: 0.144000; val_acc: 0.133000
# (Iteration 11 / 200) loss: 2.130824
# (Iteration 21 / 200) loss: 1.934641
# (Iteration 31 / 200) loss: 1.843231
# (Epoch 1 / 5) train acc: 0.375000; val_acc: 0.307000
# (Iteration 41 / 200) loss: 1.863645
# (Iteration 51 / 200) loss: 1.922827
# (Iteration 61 / 200) loss: 1.674933
# (Iteration 71 / 200) loss: 1.690505
# (Epoch 2 / 5) train acc: 0.419000; val_acc: 0.354000
# (Iteration 81 / 200) loss: 1.774906
# (Iteration 91 / 200) loss: 1.570742
# (Iteration 101 / 200) loss: 1.698551
# (Iteration 111 / 200) loss: 1.625824
# (Epoch 3 / 5) train acc: 0.478000; val_acc: 0.357000
# (Iteration 121 / 200) loss: 1.657346
# (Iteration 131 / 200) loss: 1.546019
# (Iteration 141 / 200) loss: 1.410802
# (Iteration 151 / 200) loss: 1.319939
# (Epoch 4 / 5) train acc: 0.479000; val_acc: 0.357000
# (Iteration 161 / 200) loss: 1.466964
# (Iteration 171 / 200) loss: 1.431479
# (Iteration 181 / 200) loss: 1.275051
# (Iteration 191 / 200) loss: 1.275345
# (Epoch 5 / 5) train acc: 0.522000; val_acc: 0.369000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# Because the $\frac{\text{learning\_rate}}{\text{dw}}$ is monotonically increasing with iterations. Adam don't have this issue. Adam used the exponetial average, and so the $\frac{\text{learning\_rate}}{\text{dw}}$ isn't monotonically increasing but dependent on both the history sum and current m or v.

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

np.random.seed(231)
    
# Try training a very deep net with batchnorm.
hidden_dims = [100, 100, 100]
num_train = 49000
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}
n_epochs=10
batch_sizes = 128
weight_scale = 1e-3
learning_rate = 1e-2
print_every = 1000

model = FullyConnectedNet(
    hidden_dims,
    weight_scale=weight_scale,
    dtype=np.float64,
    normalization="batchnorm"
)
solver = Solver(
    model,
    small_data,
    print_every=print_every,
    num_epochs=n_epochs,
    batch_size=batch_sizes,
    update_rule='sgd_momentum',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

best_model = model

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 3820) loss: 2.301655
# (Epoch 0 / 10) train acc: 0.141000; val_acc: 0.165000
# (Epoch 1 / 10) train acc: 0.463000; val_acc: 0.457000
# (Epoch 2 / 10) train acc: 0.522000; val_acc: 0.516000
# (Iteration 1001 / 3820) loss: 1.209138
# (Epoch 3 / 10) train acc: 0.543000; val_acc: 0.521000
# (Epoch 4 / 10) train acc: 0.572000; val_acc: 0.539000
# (Epoch 5 / 10) train acc: 0.585000; val_acc: 0.540000
# (Iteration 2001 / 3820) loss: 1.049019
# (Epoch 6 / 10) train acc: 0.616000; val_acc: 0.504000
# (Epoch 7 / 10) train acc: 0.614000; val_acc: 0.532000
# (Iteration 3001 / 3820) loss: 0.930404
# (Epoch 8 / 10) train acc: 0.638000; val_acc: 0.551000
# (Epoch 9 / 10) train acc: 0.661000; val_acc: 0.526000
# (Epoch 10 / 10) train acc: 0.637000; val_acc: 0.532000

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.537
# Test set accuracy:  0.517
